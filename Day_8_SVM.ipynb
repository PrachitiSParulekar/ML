# %% [markdown]
# <a href="https://colab.research.google.com/github/PrachitiSParulekar/ML/blob/main/Day_8_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.datasets import make_classification
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import pandas as pd

plt.style.use('default')
sns.set_palette("husl")

# %%
#svm linear

# 1. Generate synthetic data
X_linear, y_linear = make_classification(
    n_samples=200, n_features=2, n_redundant=0,
    n_informative=2, n_clusters_per_class=1,
    random_state=42
)


# 2. Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_linear, y_linear, test_size=0.3, random_state=42
)


# 3. Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


# 4. Train SVM
svm_linear = SVC(kernel='linear', C=1.0, random_state=42)
svm_linear.fit(X_train_scaled, y_train)
y_pred = svm_linear.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
print(f"Linear SVM Accuracy: {accuracy:.4f}")
print(f"Support Vectors: {svm_linear.n_support_}")

# 5. Plot decision boundary
plt.figure(figsize=(10, 8))
X_plot = scaler.inverse_transform(X_train_scaled)

# Generate the mesh grid for contour plot
h = 0.02
x_min, x_max = X_plot[:, 0].min() - 1, X_plot[:, 0].max() + 1
y_min, y_max = X_plot[:, 1].min() - 1, X_plot[:, 1].max() + 1
xx, yy = np.meshgrid(
    np.arange(x_min, x_max, h),
    np.arange(y_min, y_max, h)
)
mesh_points = np.c_[xx.ravel(), yy.ravel()]
mesh_points_scaled = scaler.transform(mesh_points)

Z = svm_linear.predict(mesh_points_scaled)
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.RdYlBu)

# Plot training points
scatter = plt.scatter(X_plot[:, 0], X_plot[:, 1], c=y_train, cmap=plt.cm.RdYlBu, edgecolors='black')

# Highlight support vectors
support_vectors = scaler.inverse_transform(svm_linear.support_vectors_)
plt.scatter(
    support_vectors[:, 0], support_vectors[:, 1],
    s=100, facecolors='none', edgecolors='red', linewidth=2, label='Support Vectors'
)

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'Linear SVM Decision Boundary (Accuracy: {accuracy:.4f})')
plt.legend()
plt.colorbar(scatter)
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Linear SVM Accuracy: 0.8667
# Support Vectors: [30 29]

# %%
#svm non linear
# 1. Generate synthetic non-linear data (concentric circles)
X_nonlinear, y_nonlinear = make_circles(
    n_samples=200, noise=0.1, factor=0.3, random_state=42
)


# 2. Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_nonlinear, y_nonlinear, test_size=0.3, random_state=42
)


# 3. Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


# 4. Train SVM with RBF kernel (for non-linear separation)
svm_rbf = SVC(kernel='rbf', C=1.0, gamma='scale', random_state=42)
svm_rbf.fit(X_train_scaled, y_train)
y_pred = svm_rbf.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
print(f"RBF SVM Accuracy: {accuracy:.4f}")
print(f"Support Vectors: {svm_rbf.n_support_}")

# 5. Plot decision boundary (no function used!)
plt.figure(figsize=(10, 8))
X_plot = scaler.inverse_transform(X_train_scaled)

h = 0.02
x_min, x_max = X_plot[:, 0].min() - 1, X_plot[:, 0].max() + 1
y_min, y_max = X_plot[:, 1].min() - 1, X_plot[:, 1].max() + 1
xx, yy = np.meshgrid(
    np.arange(x_min, x_max, h),
    np.arange(y_min, y_max, h)
)
mesh_points = np.c_[xx.ravel(), yy.ravel()]
mesh_points_scaled = scaler.transform(mesh_points)

Z = svm_rbf.predict(mesh_points_scaled)
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.RdYlBu)

# Plot training points
scatter = plt.scatter(X_plot[:, 0], X_plot[:, 1], c=y_train, cmap=plt.cm.RdYlBu, edgecolors='black')

# Highlight support vectors
support_vectors = scaler.inverse_transform(svm_rbf.support_vectors_)
plt.scatter(
    support_vectors[:, 0], support_vectors[:, 1],
    s=100, facecolors='none', edgecolors='red', linewidth=2, label='Support Vectors'
)

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'RBF SVM Decision Boundary (Accuracy: {accuracy:.4f})')
plt.legend()
plt.colorbar(scatter)
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# RBF SVM Accuracy: 1.0000
# Support Vectors: [13 10]

# %%
#svm poly
# 1. Generate synthetic non-linear data (concentric circles)
X_poly, y_poly = make_circles(
    n_samples=200, noise=0.1, factor=0.3, random_state=42
)


# 2. Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_poly, y_poly, test_size=0.3, random_state=42
)


# 3. Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


# 4. Train SVM with polynomial kernel (degree 3 is standard)
svm_poly = SVC(kernel='poly', degree=3, C=1.0, gamma='scale', random_state=42)
svm_poly.fit(X_train_scaled, y_train)
y_pred = svm_poly.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
print(f"Polynomial SVM Accuracy: {accuracy:.4f}")
print(f"Support Vectors: {svm_poly.n_support_}")

# 5. Plot decision boundary (no function used!)
plt.figure(figsize=(10, 8))
X_plot = scaler.inverse_transform(X_train_scaled)

h = 0.02
x_min, x_max = X_plot[:, 0].min() - 1, X_plot[:, 0].max() + 1
y_min, y_max = X_plot[:, 1].min() - 1, X_plot[:, 1].max() + 1
xx, yy = np.meshgrid(
    np.arange(x_min, x_max, h),
    np.arange(y_min, y_max, h)
)
mesh_points = np.c_[xx.ravel(), yy.ravel()]
mesh_points_scaled = scaler.transform(mesh_points)

Z = svm_poly.predict(mesh_points_scaled)
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.RdYlBu)

# Plot training points
scatter = plt.scatter(X_plot[:, 0], X_plot[:, 1], c=y_train, cmap=plt.cm.RdYlBu, edgecolors='black')

# Highlight support vectors
support_vectors = scaler.inverse_transform(svm_poly.support_vectors_)
plt.scatter(
    support_vectors[:, 0], support_vectors[:, 1],
    s=100, facecolors='none', edgecolors='red', linewidth=2, label='Support Vectors'
)

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'Polynomial SVM Decision Boundary (Accuracy: {accuracy:.4f})')
plt.legend()
plt.colorbar(scatter)
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Polynomial SVM Accuracy: 0.5667
# Support Vectors: [67 66]

# %%
#svm rbf
# 1. Generate synthetic non-linear data (concentric circles)
X_rbf, y_rbf = make_circles(
    n_samples=200, noise=0.1, factor=0.3, random_state=42
)

# 2. Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_rbf, y_rbf, test_size=0.3, random_state=42
)



# 3. Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 4. Train SVM with RBF kernel
svm_rbf = SVC(kernel='rbf', C=1.0, gamma='scale', random_state=42)
svm_rbf.fit(X_train_scaled, y_train)
y_pred = svm_rbf.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
print(f"RBF SVM Accuracy: {accuracy:.4f}")
print(f"Support Vectors: {svm_rbf.n_support_}")


# 5. Plot decision boundary
plt.figure(figsize=(10, 8))
X_plot = scaler.inverse_transform(X_train_scaled)

h = 0.02
x_min, x_max = X_plot[:, 0].min() - 1, X_plot[:, 0].max() + 1
y_min, y_max = X_plot[:, 1].min() - 1, X_plot[:, 1].max() + 1
xx, yy = np.meshgrid(
    np.arange(x_min, x_max, h),
    np.arange(y_min, y_max, h)
)
mesh_points = np.c_[xx.ravel(), yy.ravel()]
mesh_points_scaled = scaler.transform(mesh_points)

Z = svm_rbf.predict(mesh_points_scaled)
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.RdYlBu)

# Plot training points
scatter = plt.scatter(X_plot[:, 0], X_plot[:, 1], c=y_train, cmap=plt.cm.RdYlBu, edgecolors='black')

# Highlight support vectors
support_vectors = scaler.inverse_transform(svm_rbf.support_vectors_)
plt.scatter(
    support_vectors[:, 0], support_vectors[:, 1],
    s=100, facecolors='none', edgecolors='red', linewidth=2, label='Support Vectors'
)

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'RBF SVM Decision Boundary (Accuracy: {accuracy:.4f})')
plt.legend()
plt.colorbar(scatter)
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# RBF SVM Accuracy: 1.0000
# Support Vectors: [13 10]

# %%
#svm sigmoid
# 1. Generate synthetic non-linear data (concentric circles)
X_sigmoid, y_sigmoid = make_circles(
    n_samples=200, noise=0.1, factor=0.3, random_state=42
)

# 2. Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_sigmoid, y_sigmoid, test_size=0.3, random_state=42
)
# 3. Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 4. Train SVM with sigmoid kernel
svm_sig = SVC(kernel='sigmoid', C=1.0, gamma='scale', random_state=42)
svm_sig.fit(X_train_scaled, y_train)
y_pred = svm_sig.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
print(f"Sigmoid SVM Accuracy: {accuracy:.4f}")
print(f"Support Vectors: {svm_sig.n_support_}")

# 5. Plot decision boundary (no function used!)
plt.figure(figsize=(10, 8))
X_plot = scaler.inverse_transform(X_train_scaled)
h = 0.02
x_min, x_max = X_plot[:, 0].min() - 1, X_plot[:, 0].max() + 1
y_min, y_max = X_plot[:, 1].min() - 1, X_plot[:, 1].max() + 1
xx, yy = np.meshgrid(
    np.arange(x_min, x_max, h),
    np.arange(y_min, y_max, h)
)
mesh_points = np.c_[xx.ravel(), yy.ravel()]
mesh_points_scaled = scaler.transform(mesh_points)

Z = svm_sig.predict(mesh_points_scaled)
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.RdYlBu)

scatter = plt.scatter(X_plot[:, 0], X_plot[:, 1], c=y_train, cmap=plt.cm.RdYlBu, edgecolors='black')

# Highlight support vectors
support_vectors = scaler.inverse_transform(svm_sig.support_vectors_)
plt.scatter(
    support_vectors[:, 0], support_vectors[:, 1],
    s=100, facecolors='none', edgecolors='red', linewidth=2, label='Support Vectors'
)

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title(f'Sigmoid SVM Decision Boundary (Accuracy: {accuracy:.4f})')
plt.legend()
plt.colorbar(scatter)
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Sigmoid SVM Accuracy: 0.4833
# Support Vectors: [54 55]
